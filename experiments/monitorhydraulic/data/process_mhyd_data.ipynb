# %%
using DataFrames
using CSV
using Plots
using JLD2

# %%
data = DataFrame(CSV.File("VS1.txt", header=false))
# Out:
# 2205×60 DataFrame
#   Row │ Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8 ⋯
#       │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │   0.604    0.605    0.611    0.603    0.608    0.608    0.608    0.617 ⋯
#     2 │   0.59     0.61     0.626    0.62     0.623    0.619    0.617    0.618
#     3 │   0.578    0.603    0.638    0.651    0.652    0.662    0.662    0.656
#     4 │   0.565    0.591    0.608    0.614    0.623    0.645    0.642    0.645
#     5 │   0.57     0.6      0.623    0.636    0.644    0.642    0.651    0.654 ⋯
#     6 │   0.568    0.601    0.611    0.614    0.629    0.627    0.63     0.629
#     7 │   0.582    0.605    0.629    0.635    0.634    0.642    0.642    0.649
#     8 │   0.583    0.614    0.63     0.641    0.647    0.656    0.669    0.667
# ...
